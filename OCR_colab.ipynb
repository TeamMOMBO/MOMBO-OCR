# %%
pip install --upgrade pip
# Out:
# ...
#   Using cached pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
pip install -r /content/drive/MyDrive/OCR-KOR/requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 40.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 92.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 127.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 55.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 138.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 145.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 41.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 132.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 147.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 57.9 MB/s eta 0:00:00
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/OCR-KOR')

# %%
# !python3 /content/drive/MyDrive/OCR-KOR/deep-text-recognition-benchmark/train.py --train_data /content/drive/MyDrive/OCR-KOR/data/data_lmdb_release/training --valid_data /content/drive/MyDrive/OCR-KOR/data/data_lmdb_release/validation --select_data basic-skew --batch_ratio 0.5-0.5 --Transformation TPS --FeatureExtraction VGG --SequenceModeling BiLSTM --Prediction CTC --data_filtering_off --valInterval 100 --batch_size 256 --batch_max_length 75 --workers 8 --imgW 400

# %%
# !python3 /content/drive/MyDrive/OCR-KOR/deep-text-recognition-benchmark/train.py --train_data /content/drive/MyDrive/OCR-KOR/data/data_lmdb_release/training --valid_data /content/drive/MyDrive/OCR-KOR/data/data_lmdb_release/validation --select_data basic-skew --batch_ratio 0.5-0.5 --Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction Attn --data_filtering_off --valInterval 100 --batch_size 128 --batch_max_length 50 --workers 4 --imgW 400 --continue_model  /content/drive/MyDrive/OCR-KOR/saved_models/TPS-ResNet-BiLSTM-Attn-Seed1111/best_accuracy_23800.pth
# Out:
# device count 1
# --------------------------------------------------------------------------------
# dataset_root: /content/drive/MyDrive/OCR-KOR/data/data_lmdb_release/training
# opt.select_data: ['basic', 'skew']
# opt.batch_ratio: ['0.5', '0.5']
# --------------------------------------------------------------------------------
# dataset_root:    /content/drive/MyDrive/OCR-KOR/data/data_lmdb_release/training	 dataset: basic
# sub-directory:	/basic	 num samples: 9000
# num TRDG samples of basic: 9000 x 1.0 (total_data_usage_ratio) = 9000
# num samples of basic per batch: 128 x 0.5 (batch_ratio) = 64
# --------------------------------------------------------------------------------
# dataset_root:    /content/drive/MyDrive/OCR-KOR/data/data_lmdb_release/training	 dataset: skew
# sub-directory:	/skew	 num samples: 9000
# num TRDG samples of skew: 9000 x 1.0 (total_data_usage_ratio) = 9000
# num samples of skew per batch: 128 x 0.5 (batch_ratio) = 64
# ...

# %% [markdown]
# 모델 데모

# %%
# !python3 /content/drive/MyDrive/OCR-KOR/deep-text-recognition-benchmark/demo.py --Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction Attn --image_folder /content/drive/MyDrive/OCR-KOR/data/demo_imgs --saved_model /content/drive/MyDrive/OCR-KOR/saved_models/TPS-ResNet-BiLSTM-Attn-Seed2222/best_accuracy.pth
# Out:
# model input parameters 32 400 20 1 512 256 974 50 TPS ResNet BiLSTM Attn
# loading pretrained model from /content/drive/MyDrive/OCR-KOR/saved_models/TPS-ResNet-BiLSTM-Attn-Seed2222/best_accuracy.pth
# /content/drive/MyDrive/OCR-KOR/deep-text-recognition-benchmark/demo.py:53: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   length_for_pred = torch.cuda.IntTensor([opt.batch_max_length] * batch_size)
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:4316: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# --------------------------------------------------------------------------------
# ...
